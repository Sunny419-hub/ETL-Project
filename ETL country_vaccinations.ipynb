# %% [markdown]
# **Cleaning data COVID-19 world vaccination progress**

# %% [markdown]
# **Exploring vaccination info**

# %%
# Dependencies and Setup
import pandas as pd
import csv
import os
from sqlalchemy import create_engine
from config import access

# %%
# File to Load (Remember to Change These)
file_to_load = "Resources/country_vaccinations.csv"

# Read Purchasing File and store into Pandas data frame
vaccination_data = pd.read_csv(file_to_load)
vaccination_data.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0
#
#                                             vaccines  \
# 0  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 1  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 2  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 3  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 4  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
#
#                  source_name            source_website
# 0  World Health Organization  https://covid19.who.int/
# 1  World Health Organization  https://covid19.who.int/
# 2  World Health Organization  https://covid19.who.int/
# 3  World Health Organization  https://covid19.who.int/
# 4  World Health Organization  https://covid19.who.int/

# %%
# Inspect all columns
vaccination_data.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
vaccination_data.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# dtype: object

# %%
vaccination_date = vaccination_data.loc[(vaccination_data["date"] >= "2020-12-2") & (vaccination_data["date"] <= "2021-5-28")]
vaccination_date
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 21623     Zimbabwe      ZWE  2021-05-27            953389.0
# 21624     Zimbabwe      ZWE  2021-05-28            976796.0
# 21625     Zimbabwe      ZWE  2021-05-29           1002465.0
# 21626     Zimbabwe      ZWE  2021-05-30           1011973.0
# 21627     Zimbabwe      ZWE  2021-05-31           1020078.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# 2                    NaN                      NaN                     NaN
# 3                    NaN                      NaN                     NaN
# 4                    NaN                      NaN                     NaN
# ...                  ...                      ...                     ...
# 21623           648121.0                 305268.0                 16349.0
# 21624           656630.0                 320166.0                 23407.0
# 21625           666786.0                 335679.0                 25669.0
# 21626           670755.0                 341218.0                  9508.0
# 21627           675678.0                 344400.0                  8105.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                            0.00
# 1                  1367.0                             NaN
# 2                  1367.0                             NaN
# 3                  1367.0                             NaN
# 4                  1367.0                             NaN
# ...                   ...                             ...
# 21623             12285.0                            6.41
# 21624             12695.0                            6.57
# 21625             14056.0                            6.74
# 21626             14420.0                            6.81
# 21627             15022.0                            6.86
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               0.00                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
# ...                              ...                                  ...
# 21623                           4.36                                 2.05
# 21624                           4.42                                 2.15
# 21625                           4.49                                 2.26
# 21626                           4.51                                 2.30
# 21627                           4.55                                 2.32
#
#        daily_vaccinations_per_million  \
# 0                                 NaN
# 1                                35.0
# 2                                35.0
# 3                                35.0
# 4                                35.0
# ...                               ...
# 21623                           827.0
# 21624                           854.0
# 21625                           946.0
# 21626                           970.0
# 21627                          1011.0
#
#                                                 vaccines  \
# 0      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 1      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 2      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 3      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 4      Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# ...                                                  ...
# 21623                                  Sinopharm/Beijing
# 21624                                  Sinopharm/Beijing
# 21625                                  Sinopharm/Beijing
# 21626                                  Sinopharm/Beijing
# 21627                                  Sinopharm/Beijing
#
#                      source_name  \
# 0      World Health Organization
# 1      World Health Organization
# 2      World Health Organization
# 3      World Health Organization
# 4      World Health Organization
# ...                          ...
# 21623         Ministry of Health
# 21624         Ministry of Health
# 21625         Ministry of Health
# 21626         Ministry of Health
# 21627         Ministry of Health
#
#                                           source_website
# 0                               https://covid19.who.int/
# 1                               https://covid19.who.int/
# 2                               https://covid19.who.int/
# 3                               https://covid19.who.int/
# 4                               https://covid19.who.int/
# ...                                                  ...
# 21623  https://twitter.com/MoHCCZim/status/1399441311...
# 21624  https://twitter.com/MoHCCZim/status/1399441311...
# 21625  https://twitter.com/MoHCCZim/status/1399441311...
# 21626  https://twitter.com/MoHCCZim/status/1399441311...
# 21627  https://twitter.com/MoHCCZim/status/1399441311...
#
# [21580 rows x 15 columns]

# %%
vaccination_date_country = vaccination_date.groupby(["country"]).sum()
vaccination_date_country=vaccination_date_country.reset_index()

# %%
vaccination = vaccination_date_country.loc[:, ['country','total_vaccinations','people_fully_vaccinated']]

# %%
vaccination
# Out:
#                country  total_vaccinations  people_fully_vaccinated
# 0          Afghanistan           3831799.0                 574841.0
# 1              Albania          24787760.0                3550624.0
# 2              Algeria             75030.0                      0.0
# 3              Andorra            249370.0                  31652.0
# 4               Angola           5386560.0                 669072.0
# ..                 ...                 ...                      ...
# 209              Wales         223488730.0               53934287.0
# 210  Wallis and Futuna             49977.0                  12249.0
# 211              Yemen            122625.0                      0.0
# 212             Zambia           2484910.0                  41089.0
# 213           Zimbabwe          34383423.0                7915502.0
#
# [214 rows x 3 columns]

# %%
missing_values = vaccination.isnull().sum()
missing_values
# Out:
# country                    0
# total_vaccinations         0
# people_fully_vaccinated    0
# dtype: int64

# %%
vaccination.dtypes
# Out:
# country                     object
# total_vaccinations         float64
# people_fully_vaccinated    float64
# dtype: object

# %% [markdown]
# ### Connect to local database

# %%
# Create Engine for SQL Data
engine = create_engine(f'postgresql://postgres:{access}@localhost/etl_db')
conn= engine.connect()

# %%
engine.table_names()
# Out:
# ['confirmed_cases', 'tests', 'deaths', 'vaccination', 'countries']

# %%
vaccination.to_sql(name='vaccination', con=engine, if_exists='append', index=False)
