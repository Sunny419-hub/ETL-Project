# %% [markdown]
# # Daily Confirmed Cases

# %%
#Dependencies
import pandas as pd
from sqlalchemy import create_engine
import csv
import os

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "../ETL-Project/Resources/RAW_global_confirmed_cases.csv"
confirmed_cases_df = pd.read_csv(csv_file)
confirmed_cases_df.head()
# Out:
#   Country/Region Province/State       Lat       Long  1/22/20  1/23/20  \
# 0    Afghanistan            NaN  33.93911  67.709953        0        0
# 1        Albania            NaN  41.15330  20.168300        0        0
# 2        Algeria            NaN  28.03390   1.659600        0        0
# 3        Andorra            NaN  42.50630   1.521800        0        0
# 4         Angola            NaN -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/29/21  5/30/21  5/31/21  6/1/21  \
# 0        0        0        0        0  ...    70111    70761    71838   72977
# 1        0        0        0        0  ...   132297   132309   132315  132337
# 2        0        0        0        0  ...   128456   128725   128913  129218
# 3        0        0        0        0  ...    13693    13693    13727   13729
# 4        0        0        0        0  ...    34180    34366    34551   34752
#
#    6/2/21  6/3/21  6/4/21  6/5/21  6/6/21  6/7/21
# ...

# %% [markdown]
# ### Describe Data

# %%
confirmed_cases_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Columns: 507 entries, Country/Region to 6/7/21
# dtypes: float64(2), int64(503), object(2)
# memory usage: 1.1+ MB

# %%
confirmed_cases_df.dtypes
# Out:
# Country/Region     object
# Province/State     object
# Lat               float64
# Long              float64
# 1/22/20             int64
#                    ...
# 6/3/21              int64
# 6/4/21              int64
# 6/5/21              int64
# 6/6/21              int64
# 6/7/21              int64
# Length: 507, dtype: object

# %% [markdown]
# ### Create a summary variable

# %%
 #new variable with total confirmed cases until may 28th 2021
confirmed_cases_df['total_confirmed']= confirmed_cases_df.iloc[:, 320:497].sum(axis=1)  
confirmed_cases_df
# Out:
#          Country/Region Province/State        Lat        Long  1/22/20  \
# 0           Afghanistan            NaN  33.939110   67.709953        0
# 1               Albania            NaN  41.153300   20.168300        0
# 2               Algeria            NaN  28.033900    1.659600        0
# 3               Andorra            NaN  42.506300    1.521800        0
# 4                Angola            NaN -11.202700   17.873900        0
# ..                  ...            ...        ...         ...      ...
# 271             Vietnam            NaN  14.058324  108.277199        0
# 272  West Bank and Gaza            NaN  31.952200   35.233200        0
# 273               Yemen            NaN  15.552727   48.516388        0
# 274              Zambia            NaN -13.133897   27.849332        0
# 275            Zimbabwe            NaN -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  5/30/21  5/31/21  \
# ...

# %%
confirmed_cases_df= confirmed_cases_df.rename(columns={'Country/Region': 'country','Lat': 'lat','Long': 'long'})
confirmed_cases_df
# Out:
#                 country Province/State        lat        long  1/22/20  \
# 0           Afghanistan            NaN  33.939110   67.709953        0
# 1               Albania            NaN  41.153300   20.168300        0
# 2               Algeria            NaN  28.033900    1.659600        0
# 3               Andorra            NaN  42.506300    1.521800        0
# 4                Angola            NaN -11.202700   17.873900        0
# ..                  ...            ...        ...         ...      ...
# 271             Vietnam            NaN  14.058324  108.277199        0
# 272  West Bank and Gaza            NaN  31.952200   35.233200        0
# 273               Yemen            NaN  15.552727   48.516388        0
# 274              Zambia            NaN -13.133897   27.849332        0
# 275            Zimbabwe            NaN -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  5/30/21  5/31/21  \
# ...

# %%
confirmed_cases_df=confirmed_cases_df.groupby(["country"]).sum()
confirmed_cases_df=confirmed_cases_df.reset_index()

# %% [markdown]
# ### Keep the required variables

# %%
confirmed_cases_df=confirmed_cases_df.loc[:, ["country", "total_confirmed"]]

# %%
duplicate = confirmed_cases_df[confirmed_cases_df.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [country, total_confirmed]
# Index: []

# %% [markdown]
# ### Connect to local database

# %%
# Create Engine for SQL Data
engine = create_engine('postgresql://postgres:sql2021@localhost/etl_db')
conn= engine.connect()

# %%
engine.table_names()
# Out:
# ['confirmed_cases', 'tests', 'deaths', 'vaccination']

# %%
confirmed_cases_df.to_sql(name='confirmed_cases', con=engine, if_exists='append', index=False)
