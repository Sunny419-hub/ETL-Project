# %%
# Dependencies

import csv
import pandas as pd
import os

# %%
csvpath = ("Resources/worldometer_coronavirus_daily_data.csv")

# %%
coronavirus_daily = pd.read_csv(csvpath)

# %%
coronavirus_daily
# Out:
#              date      country  cumulative_total_cases  daily_new_cases  \
# 0       2020-2-15  Afghanistan                     0.0              NaN
# 1       2020-2-16  Afghanistan                     0.0              NaN
# 2       2020-2-17  Afghanistan                     0.0              NaN
# 3       2020-2-18  Afghanistan                     0.0              NaN
# 4       2020-2-19  Afghanistan                     0.0              NaN
# ...           ...          ...                     ...              ...
# 103199  2021-5-24     Zimbabwe                 38696.0             14.0
# 103200  2021-5-25     Zimbabwe                 38706.0             10.0
# 103201  2021-5-26     Zimbabwe                 38819.0            113.0
# 103202  2021-5-27     Zimbabwe                 38854.0             35.0
# 103203  2021-5-28     Zimbabwe                 38918.0             64.0
#
#         active_cases  cumulative_total_deaths  daily_new_deaths
# ...

# %%
corona_date = coronavirus_daily.loc[(coronavirus_daily["date"] >= "2020-12-2") & (coronavirus_daily["date"] <= "2021-5-28")]

# %%
corona_date
# Out:
#              date      country  cumulative_total_cases  daily_new_cases  \
# 0       2020-2-15  Afghanistan                     0.0              NaN
# 1       2020-2-16  Afghanistan                     0.0              NaN
# 2       2020-2-17  Afghanistan                     0.0              NaN
# 3       2020-2-18  Afghanistan                     0.0              NaN
# 4       2020-2-19  Afghanistan                     0.0              NaN
# ...           ...          ...                     ...              ...
# 103199  2021-5-24     Zimbabwe                 38696.0             14.0
# 103200  2021-5-25     Zimbabwe                 38706.0             10.0
# 103201  2021-5-26     Zimbabwe                 38819.0            113.0
# 103202  2021-5-27     Zimbabwe                 38854.0             35.0
# 103203  2021-5-28     Zimbabwe                 38918.0             64.0
#
#         active_cases  cumulative_total_deaths  daily_new_deaths
# ...

# %%
corona_date_country = corona_date.groupby(["country"]).sum()

# %%
corona_date_country
# Out:
#                            cumulative_total_cases  daily_new_cases  \
# country
# Afghanistan                            13521297.0          58842.0
# Albania                                17373683.0          93390.0
# Algeria                                22084613.0          84946.0
# Andorra                                 1951460.0           8182.0
# Angola                                  3790107.0          22289.0
# ...                                           ...              ...
# Wallis And Futuna Islands                 32123.0            441.0
# Western Sahara                             3157.0              6.0
# Yemen                                    790120.0           6669.0
# Zambia                                 12056644.0          90567.0
# Zimbabwe                                5714734.0          34604.0
#
#                            active_cases  cumulative_total_deaths  \
# country
# Afghanistan                   2393941.0                 534560.0
# ...

# %%
corona_date_country.columns = ["Cumulative Total Cases","Daily New Cases","Active Cases",
                               "Cumulative Total Deaths", "Daily New Deaths"]

# %%
corona_date_country
# Out:
#                            Cumulative Total Cases  Daily New Cases  \
# country
# Afghanistan                            13521297.0          58842.0
# Albania                                17373683.0          93390.0
# Algeria                                22084613.0          84946.0
# Andorra                                 1951460.0           8182.0
# Angola                                  3790107.0          22289.0
# ...                                           ...              ...
# Wallis And Futuna Islands                 32123.0            441.0
# Western Sahara                             3157.0              6.0
# Yemen                                    790120.0           6669.0
# Zambia                                 12056644.0          90567.0
# Zimbabwe                                5714734.0          34604.0
#
#                            Active Cases  Cumulative Total Deaths  \
# country
# Afghanistan                   2393941.0                 534560.0
# ...
