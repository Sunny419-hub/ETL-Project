# %%
# Dependencies

import csv
import pandas as pd
import os

# %%
csvpath = ("Resources/worldometer_coronavirus_summary_data.csv")

# %%
coronavirus_summary = pd.read_csv(csvpath)

# %%
coronavirus_summary
# Out:
#                        country          continent  total_confirmed  \
# 0                  Afghanistan               Asia            70111
# 1                      Albania             Europe           132285
# 2                      Algeria             Africa           128198
# 3                      Andorra             Europe            13693
# 4                       Angola             Africa            33944
# ..                         ...                ...              ...
# 215  Wallis And Futuna Islands  Australia/Oceania              445
# 216             Western Sahara             Africa               10
# 217                      Yemen               Asia             6723
# 218                     Zambia             Africa            94430
# 219                   Zimbabwe             Africa            38918
#
#      total_deaths  total_recovered  active_cases  serious_or_critical  \
# 0          2899.0            57119         10093               1124.0
# ...

# %%
coronavirus_summary.columns = ("Country","Continent","Total Confirmed","Total Deaths","Total Recovered"
                         , "Active Cases","Serious or Critical","Total Cases per 1m Populaiton",
                         "Total Deaths per 1m Population", "Total Tests","Total Tests Per 1m Population", "Population")

# %%
coronavirus_summary
# Out:
#                        Country          Continent  Total Confirmed  \
# 0                  Afghanistan               Asia            70111
# 1                      Albania             Europe           132285
# 2                      Algeria             Africa           128198
# 3                      Andorra             Europe            13693
# 4                       Angola             Africa            33944
# ..                         ...                ...              ...
# 215  Wallis And Futuna Islands  Australia/Oceania              445
# 216             Western Sahara             Africa               10
# 217                      Yemen               Asia             6723
# 218                     Zambia             Africa            94430
# 219                   Zimbabwe             Africa            38918
#
#      Total Deaths  Total Recovered  Active Cases  Serious or Critical  \
# 0          2899.0            57119         10093               1124.0
# ...
